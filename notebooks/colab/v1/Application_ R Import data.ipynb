# %% [markdown]
# <a href="https://githubtocolab.com/sourceoftruthdata/sot-colab-public/blob/main/notebooks/colab/v1/Application_%20R%20Import%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Be sure that the "Runtime" is set for R
 #  colab.to/r

# %%
################################ 
# We will collect data from NYSE
################################

url_nyse = "http://ftp.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt"

investmentData = read.csv(url_nyse, sep ='|')

# %%
dim(investmentData)
# Out:
# [1] 9741   12

# %%
head(investmentData)
# Out:
#   Nasdaq.Traded Symbol
# 1 Y             A
# 2 Y             AA
# 3 Y             AAA
# 4 Y             AAAU
# 5 Y             AAC.U
# 6 Y             AACG
#   Security.Name
# 1 Agilent Technologies, Inc. Common Stock
# 2 Alcoa Corporation Common Stock
# 3 Listed Funds Trust AAF First Priority CLO Bond ETF
# 4 Goldman Sachs Physical Gold ETF Shares
# 5 Ares Acquisition Corporation Units, each consisting of one Class A ordinary share, and one-fifth of one redeemable warrant
# 6 ATA Creativity Global - American Depositary Shares, each representing two common shares
#   Listing.Exchange Market.Category ETF Round.Lot.Size Test.Issue
# 1 N                                N   100            N
# 2 N                                N   100            N
# 3 P                                Y   100            N
# 4 P                                Y   100            N
# 5 N                                N   100            N
# 6 Q                G               N   100            N
# ...

# %%
# Notice the slight syntax difference

# dim(investmentData) = investmentData.shape
# head(investmentData) = investmentData.head()

# %%
table(investmentData['Nasdaq.Traded'])
# Out:
# File Creation Time: 0203202118:03                                 N
#                                 1                                 1
#                                 Y
#                              9739
