# %% [markdown]
# <a href="https://githubtocolab.com/sourceoftruthdata/sot-colab-public/blob/main/notebooks/colab/v1/Application_%20R%20basics%20using%20weather%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We will import Weather data an plot Temperature by Day
# https://datahub.io/core/global-temp

# %%
weatherData = read.csv('https://datahub.io/core/global-temp/r/annual.csv')

# %%
dim(weatherData)
# Out:
# [1] 274   3

# %%
# the data has 274 rows and 3 columns

# %%
head(weatherData)
# Out:
#   Source  Year Mean
# 1 GCAG    2016 0.9363
# 2 GISTEMP 2016 0.9900
# 3 GCAG    2015 0.8998
# 4 GISTEMP 2015 0.8700
# 5 GCAG    2014 0.7408
# 6 GISTEMP 2014 0.7400

# %%
# Let's select on GISTEMP data

# %%
table(weatherData$Source)
# Out:
#    GCAG GISTEMP
#     137     137

# %%
# We should expect 137 rows and 3 columns

# %%
#
gisTemp = weatherData[weatherData$Source == 'GISTEMP',]

# %%
head(gisTemp)
# Out:
#    Source  Year Mean
# 2  GISTEMP 2016 0.99
# 4  GISTEMP 2015 0.87
# 6  GISTEMP 2014 0.74
# 8  GISTEMP 2013 0.65
# 10 GISTEMP 2012 0.63
# 12 GISTEMP 2011 0.60

# %%
# Let's plot the data by Year

# %%
plot(gisTemp$Year, gisTemp$Mean)
grid()
# Out:
# plot without title

# %%
# There are subtle difference between R and Python

# %%
# Next we will add a smooth line through this data!
