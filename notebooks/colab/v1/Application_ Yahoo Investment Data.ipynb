# %% [markdown]
# <a href="https://githubtocolab.com/sourceoftruthdata/sot-colab-public/blob/main/notebooks/colab/v1/Application_%20Yahoo%20Investment%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generation of Yahoo Sourced Investment Data with Python

# %% [markdown]
# # Introduction
#
# We will pull Stock data from Yahoo

# %%
########################
# Load packages
########################

# issues
# https://github.com/pydata/pandas-datareader/issues/962

import pandas as pd
import datetime

from pandas_datareader.data import get_quote_yahoo
import matplotlib.pyplot as plt

# %%
########################
# Pull a Single days price (most recent)
########################

myTicker = 'F'

get_quote_yahoo(myTicker).price
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-3-08c36d1bf25a> in <cell line: 7>()
#       5 myTicker = 'F'
#       6
# ----> 7 get_quote_yahoo(myTicker).price
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/data.py in get_quote_yahoo(*args, **kwargs)
#      94
#      95 def get_quote_yahoo(*args, **kwargs):
# ---> 96     return YahooQuotesReader(*args, **kwargs).read()
#      97
#      98
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/yahoo/quotes.py in read(self)
#      47     def read(self):
#      48         if isinstance(self.symbols, string_types):
# ---> 49             return self._read_one_data(self.url, self.params(self.symbols))
#      50         else:
#      51             data = OrderedDict()
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/base.py in _read_one_data(self, url, params)
# ...

# %%
##############################
# Let's pull more data
# by defining Start and End Date
# END date will default to most recent date
##############################

start = datetime.datetime(2021, 1, 1)

#########################
# here arbirtraty ticker input
# note that excluding "end" will extract current data
#########################

df = web.DataReader(myTicker, 'yahoo', start)

# %%
df

# %%
df['Close'].plot()
plt.grid()
