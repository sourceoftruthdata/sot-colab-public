# %% [markdown]
# <a href="https://githubtocolab.com/sourceoftruthdata/sot-colab-public/blob/main/notebooks/colab/v1/Introduction_%20First%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My First Notebook
#
# ## This is how you use the Notebook

# %%
# this is how to Comment things, by adding an '#' before text
# Comments are helpful to test and debug a cells or lines of codes
# Many times I will use the following format to informally denote a SECTION

##################
# SECTION.       #
##################

# What you will learn in this LESSON:
# 1) Cell Structure
# 2) Commenting
# 3) Cell Execution
# 4) Printing to screen
# 5) Data Awesomeness
# 6) Insert Cell
# 7) Delete Cell
# Keywords: 
# 1) Notebook
# 2) Cell
# 3) Comment
# 4) Print
# 5) Execution
# 6) Insert
# 7) Delete

# This is a NOTEBOOK CELL
# pressing the PLAY button to the left will "evaluate" a CELL
# This NOTEBOOK is how we will CODE (write and evaluate PYTHON code)
# SELECTING A NOTEBOOK CELL will make the selected CELL active

# 1) Select the CELL below and EVALUATE the code (PRESS PLAY)

# %%
print('Congratulations! You just evaluated a NOTEBOOK CELL today')
# Out:
# Congratulations! You just evaluated a NOTEBOOK CELL today

# %% [markdown]
# # Using Notebooks

# %%
# A new cell can be entered by Select Insert>Code Cell
# Or by select the Mac Shortcut CMD-M-B
# Or by select ESC then B
# Try to Select ESC then A: What happened?

# %%
print("I can add a Cell Bellow")
# Out:
# I can add a Cell Bellow

# %%
# There are many different Jupyter versions, for our purposes we are using Google Colab
# Code can be executed with CTRL-RET
# Notice the CELL INDEX will ITERATE

# %% [markdown]
# # Code Execution

# %%
import pandas as pd

# %%
investData = pd.read_csv('https://dumbstockapi.com/stock?format=csv&countries=US')

# %%
investData.shape
# Out:
# (6973, 4)

# %%
investData.dtypes
# Out:
# ticker       object
# name         object
# is_etf      float64
# exchange     object
# dtype: object

# %%
 # Extra Comment
