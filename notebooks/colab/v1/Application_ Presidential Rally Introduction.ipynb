# %% [markdown]
# # Import Packages

# %%
#####################
# Import packages
#####################

import pandas as pd
import plotly.graph_objects as go

# Importing new packages for this notebook

import numpy as np
import datetime as dt
from dateutil import parser
import os

# Graphs

import matplotlib.pyplot as plt

# %% [markdown]
# # Rally Data

# %%
dfs = pd.read_html("https://en.wikipedia.org/wiki/List_of_post-2016_election_Donald_Trump_rallies", header=0)
for df in dfs:
    print(df)
# Out:
#   This article is part of a series aboutDonald Trump                                         Unnamed: 1
# 0                                                NaN  This article is part of a series aboutDonald T...
# 1  Political positions Electoral history Business...                                                NaN
# 2  .mw-parser-output .navbar{display:inline;font-...                                                NaN
# Empty DataFrame
# Columns: [Unnamed: 0, This article is part of a series aboutDonald Trump]
# Index: []
#                     Date of rally  ...                                     Other speakers
# 0   Thursday, December 1, 2016[1]  ...  Josh Mandel, Stephen Miller, Matt Bevin, Mike ...
# 1    Tuesday, December 6, 2016[2]  ...  Jimmy Dixon, Nat Robertson, Cherie Berry, Robe...
# 2   Thursday, December 8, 2016[3]  ...                                         Mike Pence
# 3  Friday, December 9, 2016[4][5]  ...  Jeff Landry, Bodi White, Billy Nungesser, Ralp...
# ...

# %%
###################
# dfs #7 has data # 
# Our Rally data. #
###################

dfs[7]
# Out:
#                                         Date of rally  ...                                     Other speakers
# 0                        Saturday, June 20, 2020[111]  ...  Lara Trump, Eric Trump, Mike Pence, Diamond an...
# 1                         Tuesday, June 23, 2020[112]  ...  Donald Trump Jr., Kimberly Guilfoyle, Charlie ...
# 2                        Monday, August 17, 2020[113]  ...                                                NaN
# 3                        Monday, August 17, 2020[113]  ...                                                NaN
# 4                       Tuesday, August 18, 2020[114]  ...                                                NaN
# ..                                                ...  ...                                                ...
# 62  Monday, November 2, 2020[162][160][158][161][163]  ...                                                NaN
# ...

# %% [markdown]
# # Save the Data to a dataframe:

# %%
mydata = dfs[7]

# %%
mydata.head()
# Out:
#                    Date of rally  ...                                     Other speakers
# 0   Saturday, June 20, 2020[111]  ...  Lara Trump, Eric Trump, Mike Pence, Diamond an...
# 1    Tuesday, June 23, 2020[112]  ...  Donald Trump Jr., Kimberly Guilfoyle, Charlie ...
# 2   Monday, August 17, 2020[113]  ...                                                NaN
# 3   Monday, August 17, 2020[113]  ...                                                NaN
# 4  Tuesday, August 18, 2020[114]  ...                                                NaN
#
# [5 rows x 5 columns]
