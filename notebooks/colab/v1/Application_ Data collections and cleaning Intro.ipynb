# %% [markdown]
# # Investment Data Quick Example

# %%
#####################
# Import packages
#####################

import pandas as pd

# %% [markdown]
# # Data Import

# %%
################################ 
# We will collect data from NYSE
################################

url_nyse = "http://ftp.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt"

investmentData = pd.read_csv(url_nyse, sep ='|', header= 0 )

# %%
investmentData
# Out:
#                           Nasdaq Traded Symbol  ... NASDAQ Symbol NextShares
# 0                                     Y      A  ...             A          N
# 1                                     Y     AA  ...            AA          N
# 2                                     Y    AAA  ...           AAA          N
# 3                                     Y   AAAU  ...          AAAU          N
# 4                                     Y   AACG  ...          AACG          N
# ...                                 ...    ...  ...           ...        ...
# 9499                                  Y  ZXZZT  ...         ZXZZT          N
# 9500                                  Y   ZYME  ...          ZYME          N
# 9501                                  Y   ZYNE  ...          ZYNE          N
# 9502                                  Y   ZYXI  ...          ZYXI          N
# 9503  File Creation Time: 1228202014:03    NaN  ...           NaN        NaN
#
# [9504 rows x 12 columns]
